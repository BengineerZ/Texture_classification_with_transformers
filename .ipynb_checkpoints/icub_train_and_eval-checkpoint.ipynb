# %%
import time
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# utils imports
import utils.data as data
import utils.model as model
import utils.training as training

# %%
'''## Test model:

generate a model with: 
2 layers, 
model dimension of 24, 
4 attention heads, 
feed forward network depth of 64, 
maximum sequence context of 400,
using the biotac embedding mechanism (single hidden layer mlp for learned embedding)

''' 
test_model = model.TransformerClassifier(2, 24, 4, 64, 75, embedding=model.icub_embedding)

## Provide arbitrary input sequence and check output spec
temp_input = tf.random.uniform((1,43,6,10,1), dtype=tf.float32, minval=0, maxval=3)
fn_out = test_model(temp_input, training=False,enc_padding_mask=None,)
print(fn_out)
# Out:
# tf.Tensor(
# [[0.07455794 0.00998235 0.0105017  0.08655114 0.19165896 0.06356382
#   0.02080919 0.0390875  0.03862402 0.04715006 0.00935917 0.05010971
#   0.03186759 0.02327801 0.0578065  0.02030383 0.05761107 0.03698672
#   0.05111049 0.07908025]], shape=(1, 20), dtype=float32)

# %%
## Summary of the transformer classifier:
test_model.summary()
# Out:
# Model: "transformer_classifier_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_1 (Encoder)          multiple                  14296
# _________________________________________________________________
# global_average_pooling1d_1 ( multiple                  0
# _________________________________________________________________
# dropout_12 (Dropout)         multiple                  0
# _________________________________________________________________
# dense_28 (Dense)             multiple                  800
# _________________________________________________________________
# dropout_13 (Dropout)         multiple                  0
# _________________________________________________________________
# dense_29 (Dense)             multiple                  660
# =================================================================
# Total params: 15,756
# Trainable params: 15,756
# Non-trainable params: 0
# _________________________________________________________________

# %%
def train_and_eval_k_fold(k):
    ''' Helper function which bundles the training and validation loops into a single function call
    Args:
        k - dataset fold - int [0,3]
    Returns:
        val_accuracy - overall accuracy on the validation dataset for final classification
        sequential_val_accuracy - sequential accuracy on the validation dataset for varying length inputs
    '''
    
    # Load, process and batch the dataset fold k
    datasets = data.load_data("path/to/dataset/BioTac_slide_20_50/compiled_data/",
                                        k = k,
                                        batch_size=40)
    train_ds = datasets['icub']['train']
    val_ds = datasets['icub']['val']
    
    # Generate the specific optimizer
    learning_rate = training.CustomSchedule(24, warmup_steps=400)
    optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98,
                                         epsilon=1e-9)
    
    # Generate the specific model
    transformer = model.TransformerClassifier(2, 24, 4, 64, 75, embedding=model.icub_embedding)
    
    # Initialise the model checkpoint system
    checkpoint_path = f"./icub_testing/checkpoints_fold_{k}/train"
    ckpt = tf.train.Checkpoint(transformer=transformer,
                               optimizer=optimizer)
    ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)
    # if a checkpoint exists, restore the latest checkpoint.
    if ckpt_manager.latest_checkpoint:
        ckpt.restore(ckpt_manager.latest_checkpoint)
        print('Latest checkpoint restored!!')
        
    
    # Generate input signature of UNKNOWN sequence length
    train_step_signature = [
        tf.TensorSpec(shape=(None, None, 6, 10, 1), dtype=tf.float32),
        tf.TensorSpec(shape=(None,), dtype=tf.float32),
    ]
    
    # Using sparse categorical cross entropy loss
    loss_object = tf.keras.losses.SparseCategoricalCrossentropy()
    
    # Define individual training step
    @tf.function(input_signature=train_step_signature)
    def train_step(inp_seq, material):

        with tf.GradientTape() as tape:
            predictions = transformer(inp_seq, True, None)
            loss = loss_object(material, predictions)

        gradients = tape.gradient(loss, transformer.trainable_variables)
        optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))

        return predictions, loss
    
    # define number of epochs
    num_epochs = 600
    
    # Run the training sequence for num_epochs
    for epoch in range(num_epochs):
        start = time.time()

        epoch_loss_avg = tf.keras.metrics.Mean()
        epoch_accuracy = tf.keras.metrics.SparseCategoricalAccuracy()

        for (batch, (inp, tar)) in enumerate(train_ds):
            # train with random sequence length
            seq_length = tf.random.uniform(shape=[],minval=1, maxval=76, dtype=tf.int64) 
            predictions, loss = train_step(inp[:,0:seq_length,...], tar)
            epoch_loss_avg.update_state(loss)
            epoch_accuracy.update_state(tar, predictions)

        if (epoch+1) % 5 == 0:
            ckpt_save_path = ckpt_manager.save()
            print(f'Saving checkpoint for epoch {epoch+1} at {ckpt_save_path}')

            print(f'Epoch {epoch + 1} Loss {epoch_loss_avg.result():.4f} Accuracy {epoch_accuracy.result():.4f}')

            print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')
    
    ## begin validation on final classification as well as sequential classification
    print("."*80)
    
    print(f"Starting eval on fold {k} ...")
    
    val_accuracy = tf.keras.metrics.SparseCategoricalAccuracy()
    for (batch, (inp, tar)) in enumerate(val_ds):
            predictions = transformer(inp, False, None)
            val_accuracy.update_state(tar, predictions)
    print(f"Test dataset accuracy: {val_accuracy.result():.4f}")
    
    print(f"Starting sequence eval on fold {k} ...")
    
    sequential_val_accuracy = []
    for i in range(1,76):
        indiv_val_accuracy = tf.keras.metrics.SparseCategoricalAccuracy()
        for (batch, (inp, tar)) in enumerate(val_ds):
            predictions = transformer(inp[:,0:i,:], False, None)
            indiv_val_accuracy.update_state(tar, predictions)
        sequential_val_accuracy.append(indiv_val_accuracy.result())
    
    print("."*80)
        
    return val_accuracy, sequential_val_accuracy

# %%
## perform the k training and eval iteration and compute the mean results for both the overall and sequence results
overall_val_accuracy = []
overall_sequential_val_accuracy = []

for fold in range(4):
    val_accuracy, sequential_val_accuracy = train_and_eval_k_fold(fold)
    overall_val_accuracy.append(val_accuracy)
    overall_sequential_val_accuracy.append(sequential_val_accuracy)
# Out:
# Loading Datasets - k-fold =  0
# ................................................................................
# BioTac training dataset shape:  (600, 400, 19)
# Icub training dataset shape:  (600, 75, 6, 10, 1)
# BioTac validation dataset shape:  (200, 400, 19)
# Icub validation dataset shape:  (200, 75, 6, 10, 1)
# ................................................................................
# Latest checkpoint restored!!
# Saving checkpoint for epoch 5 at ./icub_testing/checkpoints_fold_0/train/ckpt-101
# Epoch 5 Loss 0.2096 Accuracy 0.9350
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 10 at ./icub_testing/checkpoints_fold_0/train/ckpt-102
# Epoch 10 Loss 0.1075 Accuracy 0.9600
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 15 at ./icub_testing/checkpoints_fold_0/train/ckpt-103
# Epoch 15 Loss 0.1534 Accuracy 0.9417
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 20 at ./icub_testing/checkpoints_fold_0/train/ckpt-104
# Epoch 20 Loss 0.1147 Accuracy 0.9650
# Time taken for 1 epoch: 0.25 secs
#
# Saving checkpoint for epoch 25 at ./icub_testing/checkpoints_fold_0/train/ckpt-105
# Epoch 25 Loss 0.1315 Accuracy 0.9550
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 30 at ./icub_testing/checkpoints_fold_0/train/ckpt-106
# Epoch 30 Loss 0.1814 Accuracy 0.9400
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 35 at ./icub_testing/checkpoints_fold_0/train/ckpt-107
# Epoch 35 Loss 0.1080 Accuracy 0.9667
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 40 at ./icub_testing/checkpoints_fold_0/train/ckpt-108
# Epoch 40 Loss 0.1334 Accuracy 0.9600
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 45 at ./icub_testing/checkpoints_fold_0/train/ckpt-109
# Epoch 45 Loss 0.2955 Accuracy 0.9000
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 50 at ./icub_testing/checkpoints_fold_0/train/ckpt-110
# Epoch 50 Loss 0.0757 Accuracy 0.9817
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 55 at ./icub_testing/checkpoints_fold_0/train/ckpt-111
# Epoch 55 Loss 0.0919 Accuracy 0.9633
# Time taken for 1 epoch: 0.18 secs
#
# Saving checkpoint for epoch 60 at ./icub_testing/checkpoints_fold_0/train/ckpt-112
# Epoch 60 Loss 0.1099 Accuracy 0.9600
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 65 at ./icub_testing/checkpoints_fold_0/train/ckpt-113
# Epoch 65 Loss 0.1223 Accuracy 0.9583
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 70 at ./icub_testing/checkpoints_fold_0/train/ckpt-114
# Epoch 70 Loss 0.1972 Accuracy 0.9283
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 75 at ./icub_testing/checkpoints_fold_0/train/ckpt-115
# Epoch 75 Loss 0.1803 Accuracy 0.9367
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 80 at ./icub_testing/checkpoints_fold_0/train/ckpt-116
# Epoch 80 Loss 0.1321 Accuracy 0.9517
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 85 at ./icub_testing/checkpoints_fold_0/train/ckpt-117
# Epoch 85 Loss 0.1698 Accuracy 0.9550
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 90 at ./icub_testing/checkpoints_fold_0/train/ckpt-118
# Epoch 90 Loss 0.0705 Accuracy 0.9733
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 95 at ./icub_testing/checkpoints_fold_0/train/ckpt-119
# Epoch 95 Loss 0.2474 Accuracy 0.9267
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 100 at ./icub_testing/checkpoints_fold_0/train/ckpt-120
# Epoch 100 Loss 0.1633 Accuracy 0.9383
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 105 at ./icub_testing/checkpoints_fold_0/train/ckpt-121
# Epoch 105 Loss 0.1027 Accuracy 0.9583
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 110 at ./icub_testing/checkpoints_fold_0/train/ckpt-122
# Epoch 110 Loss 0.1172 Accuracy 0.9617
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 115 at ./icub_testing/checkpoints_fold_0/train/ckpt-123
# Epoch 115 Loss 0.2517 Accuracy 0.9283
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 120 at ./icub_testing/checkpoints_fold_0/train/ckpt-124
# Epoch 120 Loss 0.0673 Accuracy 0.9767
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 125 at ./icub_testing/checkpoints_fold_0/train/ckpt-125
# Epoch 125 Loss 0.2098 Accuracy 0.9250
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 130 at ./icub_testing/checkpoints_fold_0/train/ckpt-126
# Epoch 130 Loss 0.1561 Accuracy 0.9350
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 135 at ./icub_testing/checkpoints_fold_0/train/ckpt-127
# Epoch 135 Loss 0.0651 Accuracy 0.9717
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 140 at ./icub_testing/checkpoints_fold_0/train/ckpt-128
# Epoch 140 Loss 0.0689 Accuracy 0.9750
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 145 at ./icub_testing/checkpoints_fold_0/train/ckpt-129
# Epoch 145 Loss 0.1579 Accuracy 0.9483
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 150 at ./icub_testing/checkpoints_fold_0/train/ckpt-130
# Epoch 150 Loss 0.0627 Accuracy 0.9783
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 155 at ./icub_testing/checkpoints_fold_0/train/ckpt-131
# Epoch 155 Loss 0.0683 Accuracy 0.9750
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 160 at ./icub_testing/checkpoints_fold_0/train/ckpt-132
# Epoch 160 Loss 0.2188 Accuracy 0.9333
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 165 at ./icub_testing/checkpoints_fold_0/train/ckpt-133
# Epoch 165 Loss 0.0799 Accuracy 0.9750
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 170 at ./icub_testing/checkpoints_fold_0/train/ckpt-134
# Epoch 170 Loss 0.0703 Accuracy 0.9767
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 175 at ./icub_testing/checkpoints_fold_0/train/ckpt-135
# Epoch 175 Loss 0.0802 Accuracy 0.9767
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 180 at ./icub_testing/checkpoints_fold_0/train/ckpt-136
# Epoch 180 Loss 0.1306 Accuracy 0.9633
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 185 at ./icub_testing/checkpoints_fold_0/train/ckpt-137
# Epoch 185 Loss 0.0797 Accuracy 0.9700
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 190 at ./icub_testing/checkpoints_fold_0/train/ckpt-138
# Epoch 190 Loss 0.0806 Accuracy 0.9700
# Time taken for 1 epoch: 0.18 secs
#
# Saving checkpoint for epoch 195 at ./icub_testing/checkpoints_fold_0/train/ckpt-139
# Epoch 195 Loss 0.3752 Accuracy 0.9100
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 200 at ./icub_testing/checkpoints_fold_0/train/ckpt-140
# Epoch 200 Loss 0.0698 Accuracy 0.9717
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 205 at ./icub_testing/checkpoints_fold_0/train/ckpt-141
# Epoch 205 Loss 0.2827 Accuracy 0.9133
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 210 at ./icub_testing/checkpoints_fold_0/train/ckpt-142
# Epoch 210 Loss 0.0653 Accuracy 0.9783
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 215 at ./icub_testing/checkpoints_fold_0/train/ckpt-143
# Epoch 215 Loss 0.0977 Accuracy 0.9650
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 220 at ./icub_testing/checkpoints_fold_0/train/ckpt-144
# Epoch 220 Loss 0.1238 Accuracy 0.9650
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 225 at ./icub_testing/checkpoints_fold_0/train/ckpt-145
# Epoch 225 Loss 0.0907 Accuracy 0.9683
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 230 at ./icub_testing/checkpoints_fold_0/train/ckpt-146
# Epoch 230 Loss 0.0727 Accuracy 0.9783
# Time taken for 1 epoch: 0.18 secs
#
# Saving checkpoint for epoch 235 at ./icub_testing/checkpoints_fold_0/train/ckpt-147
# Epoch 235 Loss 0.0611 Accuracy 0.9783
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 240 at ./icub_testing/checkpoints_fold_0/train/ckpt-148
# Epoch 240 Loss 0.0933 Accuracy 0.9667
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 245 at ./icub_testing/checkpoints_fold_0/train/ckpt-149
# Epoch 245 Loss 0.1867 Accuracy 0.9433
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 250 at ./icub_testing/checkpoints_fold_0/train/ckpt-150
# Epoch 250 Loss 0.2160 Accuracy 0.9333
# Time taken for 1 epoch: 0.16 secs
# Saving checkpoint for epoch 255 at ./icub_testing/checkpoints_fold_0/train/ckpt-151
# Epoch 255 Loss 0.2037 Accuracy 0.9317
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 260 at ./icub_testing/checkpoints_fold_0/train/ckpt-152
# Epoch 260 Loss 0.1540 Accuracy 0.9467
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 265 at ./icub_testing/checkpoints_fold_0/train/ckpt-153
# Epoch 265 Loss 0.0875 Accuracy 0.9750
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 270 at ./icub_testing/checkpoints_fold_0/train/ckpt-154
# Epoch 270 Loss 0.0855 Accuracy 0.9733
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 275 at ./icub_testing/checkpoints_fold_0/train/ckpt-155
# Epoch 275 Loss 0.1967 Accuracy 0.9433
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 280 at ./icub_testing/checkpoints_fold_0/train/ckpt-156
# Epoch 280 Loss 0.1150 Accuracy 0.9617
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 285 at ./icub_testing/checkpoints_fold_0/train/ckpt-157
# Epoch 285 Loss 0.2512 Accuracy 0.9150
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 290 at ./icub_testing/checkpoints_fold_0/train/ckpt-158
# Epoch 290 Loss 0.1041 Accuracy 0.9617
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 295 at ./icub_testing/checkpoints_fold_0/train/ckpt-159
# Epoch 295 Loss 0.0682 Accuracy 0.9717
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 300 at ./icub_testing/checkpoints_fold_0/train/ckpt-160
# Epoch 300 Loss 0.1083 Accuracy 0.9617
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 305 at ./icub_testing/checkpoints_fold_0/train/ckpt-161
# Epoch 305 Loss 0.1823 Accuracy 0.9483
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 310 at ./icub_testing/checkpoints_fold_0/train/ckpt-162
# Epoch 310 Loss 0.0947 Accuracy 0.9767
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 315 at ./icub_testing/checkpoints_fold_0/train/ckpt-163
# Epoch 315 Loss 0.2164 Accuracy 0.9433
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 320 at ./icub_testing/checkpoints_fold_0/train/ckpt-164
# Epoch 320 Loss 0.0521 Accuracy 0.9817
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 325 at ./icub_testing/checkpoints_fold_0/train/ckpt-165
# Epoch 325 Loss 0.2127 Accuracy 0.9367
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 330 at ./icub_testing/checkpoints_fold_0/train/ckpt-166
# Epoch 330 Loss 0.1211 Accuracy 0.9650
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 335 at ./icub_testing/checkpoints_fold_0/train/ckpt-167
# Epoch 335 Loss 0.0659 Accuracy 0.9767
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 340 at ./icub_testing/checkpoints_fold_0/train/ckpt-168
# Epoch 340 Loss 0.1862 Accuracy 0.9433
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 345 at ./icub_testing/checkpoints_fold_0/train/ckpt-169
# Epoch 345 Loss 0.0526 Accuracy 0.9833
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 350 at ./icub_testing/checkpoints_fold_0/train/ckpt-170
# Epoch 350 Loss 0.0873 Accuracy 0.9700
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 355 at ./icub_testing/checkpoints_fold_0/train/ckpt-171
# Epoch 355 Loss 0.0338 Accuracy 0.9817
# Time taken for 1 epoch: 0.14 secs
#
# Saving checkpoint for epoch 360 at ./icub_testing/checkpoints_fold_0/train/ckpt-172
# Epoch 360 Loss 0.0429 Accuracy 0.9817
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 365 at ./icub_testing/checkpoints_fold_0/train/ckpt-173
# Epoch 365 Loss 0.1227 Accuracy 0.9650
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 370 at ./icub_testing/checkpoints_fold_0/train/ckpt-174
# Epoch 370 Loss 0.2295 Accuracy 0.9317
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 375 at ./icub_testing/checkpoints_fold_0/train/ckpt-175
# Epoch 375 Loss 0.0730 Accuracy 0.9767
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 380 at ./icub_testing/checkpoints_fold_0/train/ckpt-176
# Epoch 380 Loss 0.0796 Accuracy 0.9667
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 385 at ./icub_testing/checkpoints_fold_0/train/ckpt-177
# Epoch 385 Loss 0.1504 Accuracy 0.9517
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 390 at ./icub_testing/checkpoints_fold_0/train/ckpt-178
# Epoch 390 Loss 0.0801 Accuracy 0.9733
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 395 at ./icub_testing/checkpoints_fold_0/train/ckpt-179
# Epoch 395 Loss 0.0482 Accuracy 0.9850
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 400 at ./icub_testing/checkpoints_fold_0/train/ckpt-180
# Epoch 400 Loss 0.1016 Accuracy 0.9617
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 405 at ./icub_testing/checkpoints_fold_0/train/ckpt-181
# Epoch 405 Loss 0.0381 Accuracy 0.9850
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 410 at ./icub_testing/checkpoints_fold_0/train/ckpt-182
# Epoch 410 Loss 0.1003 Accuracy 0.9633
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 415 at ./icub_testing/checkpoints_fold_0/train/ckpt-183
# Epoch 415 Loss 0.2172 Accuracy 0.9400
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 420 at ./icub_testing/checkpoints_fold_0/train/ckpt-184
# Epoch 420 Loss 0.1218 Accuracy 0.9567
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 425 at ./icub_testing/checkpoints_fold_0/train/ckpt-185
# Epoch 425 Loss 0.0610 Accuracy 0.9767
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 430 at ./icub_testing/checkpoints_fold_0/train/ckpt-186
# Epoch 430 Loss 0.1187 Accuracy 0.9567
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 435 at ./icub_testing/checkpoints_fold_0/train/ckpt-187
# Epoch 435 Loss 0.0461 Accuracy 0.9850
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 440 at ./icub_testing/checkpoints_fold_0/train/ckpt-188
# Epoch 440 Loss 0.2688 Accuracy 0.9400
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 445 at ./icub_testing/checkpoints_fold_0/train/ckpt-189
# Epoch 445 Loss 0.1240 Accuracy 0.9533
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 450 at ./icub_testing/checkpoints_fold_0/train/ckpt-190
# Epoch 450 Loss 0.1201 Accuracy 0.9683
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 455 at ./icub_testing/checkpoints_fold_0/train/ckpt-191
# Epoch 455 Loss 0.1241 Accuracy 0.9567
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 460 at ./icub_testing/checkpoints_fold_0/train/ckpt-192
# Epoch 460 Loss 0.0988 Accuracy 0.9667
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 465 at ./icub_testing/checkpoints_fold_0/train/ckpt-193
# Epoch 465 Loss 0.0375 Accuracy 0.9900
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 470 at ./icub_testing/checkpoints_fold_0/train/ckpt-194
# Epoch 470 Loss 0.0583 Accuracy 0.9800
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 475 at ./icub_testing/checkpoints_fold_0/train/ckpt-195
# Epoch 475 Loss 0.1417 Accuracy 0.9583
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 480 at ./icub_testing/checkpoints_fold_0/train/ckpt-196
# Epoch 480 Loss 0.1858 Accuracy 0.9467
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 485 at ./icub_testing/checkpoints_fold_0/train/ckpt-197
# Epoch 485 Loss 0.1156 Accuracy 0.9650
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 490 at ./icub_testing/checkpoints_fold_0/train/ckpt-198
# Epoch 490 Loss 0.0569 Accuracy 0.9817
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 495 at ./icub_testing/checkpoints_fold_0/train/ckpt-199
# Epoch 495 Loss 0.1252 Accuracy 0.9700
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 500 at ./icub_testing/checkpoints_fold_0/train/ckpt-200
# Epoch 500 Loss 0.2378 Accuracy 0.9083
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 505 at ./icub_testing/checkpoints_fold_0/train/ckpt-201
# Epoch 505 Loss 0.0519 Accuracy 0.9817
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 510 at ./icub_testing/checkpoints_fold_0/train/ckpt-202
# Epoch 510 Loss 0.0470 Accuracy 0.9800
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 515 at ./icub_testing/checkpoints_fold_0/train/ckpt-203
# Epoch 515 Loss 0.0392 Accuracy 0.9883
# Time taken for 1 epoch: 0.17 secs
# Saving checkpoint for epoch 520 at ./icub_testing/checkpoints_fold_0/train/ckpt-204
# Epoch 520 Loss 0.0714 Accuracy 0.9783
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 525 at ./icub_testing/checkpoints_fold_0/train/ckpt-205
# Epoch 525 Loss 0.0519 Accuracy 0.9817
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 530 at ./icub_testing/checkpoints_fold_0/train/ckpt-206
# Epoch 530 Loss 0.0390 Accuracy 0.9867
# Time taken for 1 epoch: 0.18 secs
#
# Saving checkpoint for epoch 535 at ./icub_testing/checkpoints_fold_0/train/ckpt-207
# Epoch 535 Loss 0.2341 Accuracy 0.9383
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 540 at ./icub_testing/checkpoints_fold_0/train/ckpt-208
# Epoch 540 Loss 0.0259 Accuracy 0.9933
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 545 at ./icub_testing/checkpoints_fold_0/train/ckpt-209
# Epoch 545 Loss 0.0360 Accuracy 0.9883
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 550 at ./icub_testing/checkpoints_fold_0/train/ckpt-210
# Epoch 550 Loss 0.0612 Accuracy 0.9883
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 555 at ./icub_testing/checkpoints_fold_0/train/ckpt-211
# Epoch 555 Loss 0.0515 Accuracy 0.9833
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 560 at ./icub_testing/checkpoints_fold_0/train/ckpt-212
# Epoch 560 Loss 0.1102 Accuracy 0.9633
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 565 at ./icub_testing/checkpoints_fold_0/train/ckpt-213
# Epoch 565 Loss 0.0361 Accuracy 0.9883
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 570 at ./icub_testing/checkpoints_fold_0/train/ckpt-214
# Epoch 570 Loss 0.0463 Accuracy 0.9850
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 575 at ./icub_testing/checkpoints_fold_0/train/ckpt-215
# Epoch 575 Loss 0.1373 Accuracy 0.9567
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 580 at ./icub_testing/checkpoints_fold_0/train/ckpt-216
# Epoch 580 Loss 0.0320 Accuracy 0.9850
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 585 at ./icub_testing/checkpoints_fold_0/train/ckpt-217
# Epoch 585 Loss 0.0745 Accuracy 0.9783
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 590 at ./icub_testing/checkpoints_fold_0/train/ckpt-218
# Epoch 590 Loss 0.1268 Accuracy 0.9667
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 595 at ./icub_testing/checkpoints_fold_0/train/ckpt-219
# Epoch 595 Loss 0.0516 Accuracy 0.9850
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 600 at ./icub_testing/checkpoints_fold_0/train/ckpt-220
# Epoch 600 Loss 0.0929 Accuracy 0.9617
# Time taken for 1 epoch: 0.17 secs
#
# ................................................................................
# Starting eval on fold 0 ...
# Test dataset accuracy: 0.9000
# Starting sequence eval on fold 0 ...
# ................................................................................
# Loading Datasets - k-fold =  1
# ................................................................................
# BioTac training dataset shape:  (600, 400, 19)
# Icub training dataset shape:  (600, 75, 6, 10, 1)
# BioTac validation dataset shape:  (200, 400, 19)
# Icub validation dataset shape:  (200, 75, 6, 10, 1)
# ................................................................................
# Latest checkpoint restored!!
# Saving checkpoint for epoch 5 at ./icub_testing/checkpoints_fold_1/train/ckpt-101
# Epoch 5 Loss 0.2004 Accuracy 0.9333
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 10 at ./icub_testing/checkpoints_fold_1/train/ckpt-102
# Epoch 10 Loss 0.1293 Accuracy 0.9450
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 15 at ./icub_testing/checkpoints_fold_1/train/ckpt-103
# Epoch 15 Loss 0.1440 Accuracy 0.9500
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 20 at ./icub_testing/checkpoints_fold_1/train/ckpt-104
# Epoch 20 Loss 0.1435 Accuracy 0.9600
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 25 at ./icub_testing/checkpoints_fold_1/train/ckpt-105
# Epoch 25 Loss 0.1059 Accuracy 0.9533
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 30 at ./icub_testing/checkpoints_fold_1/train/ckpt-106
# Epoch 30 Loss 0.1707 Accuracy 0.9450
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 35 at ./icub_testing/checkpoints_fold_1/train/ckpt-107
# Epoch 35 Loss 0.1668 Accuracy 0.9500
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 40 at ./icub_testing/checkpoints_fold_1/train/ckpt-108
# Epoch 40 Loss 0.0931 Accuracy 0.9717
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 45 at ./icub_testing/checkpoints_fold_1/train/ckpt-109
# Epoch 45 Loss 0.1123 Accuracy 0.9567
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 50 at ./icub_testing/checkpoints_fold_1/train/ckpt-110
# Epoch 50 Loss 0.2916 Accuracy 0.9133
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 55 at ./icub_testing/checkpoints_fold_1/train/ckpt-111
# Epoch 55 Loss 0.2851 Accuracy 0.9200
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 60 at ./icub_testing/checkpoints_fold_1/train/ckpt-112
# Epoch 60 Loss 0.2060 Accuracy 0.9450
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 65 at ./icub_testing/checkpoints_fold_1/train/ckpt-113
# Epoch 65 Loss 0.2532 Accuracy 0.9450
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 70 at ./icub_testing/checkpoints_fold_1/train/ckpt-114
# Epoch 70 Loss 0.2844 Accuracy 0.9250
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 75 at ./icub_testing/checkpoints_fold_1/train/ckpt-115
# Epoch 75 Loss 0.0969 Accuracy 0.9650
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 80 at ./icub_testing/checkpoints_fold_1/train/ckpt-116
# Epoch 80 Loss 0.0925 Accuracy 0.9667
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 85 at ./icub_testing/checkpoints_fold_1/train/ckpt-117
# Epoch 85 Loss 0.0786 Accuracy 0.9750
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 90 at ./icub_testing/checkpoints_fold_1/train/ckpt-118
# Epoch 90 Loss 0.2920 Accuracy 0.9233
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 95 at ./icub_testing/checkpoints_fold_1/train/ckpt-119
# Epoch 95 Loss 0.0702 Accuracy 0.9783
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 100 at ./icub_testing/checkpoints_fold_1/train/ckpt-120
# Epoch 100 Loss 0.1517 Accuracy 0.9517
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 105 at ./icub_testing/checkpoints_fold_1/train/ckpt-121
# Epoch 105 Loss 0.1464 Accuracy 0.9567
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 110 at ./icub_testing/checkpoints_fold_1/train/ckpt-122
# Epoch 110 Loss 0.0853 Accuracy 0.9800
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 115 at ./icub_testing/checkpoints_fold_1/train/ckpt-123
# Epoch 115 Loss 0.2066 Accuracy 0.9533
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 120 at ./icub_testing/checkpoints_fold_1/train/ckpt-124
# Epoch 120 Loss 0.0965 Accuracy 0.9650
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 125 at ./icub_testing/checkpoints_fold_1/train/ckpt-125
# Epoch 125 Loss 0.0903 Accuracy 0.9667
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 130 at ./icub_testing/checkpoints_fold_1/train/ckpt-126
# Epoch 130 Loss 0.1544 Accuracy 0.9517
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 135 at ./icub_testing/checkpoints_fold_1/train/ckpt-127
# Epoch 135 Loss 0.0771 Accuracy 0.9767
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 140 at ./icub_testing/checkpoints_fold_1/train/ckpt-128
# Epoch 140 Loss 0.0910 Accuracy 0.9717
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 145 at ./icub_testing/checkpoints_fold_1/train/ckpt-129
# Epoch 145 Loss 0.1918 Accuracy 0.9350
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 150 at ./icub_testing/checkpoints_fold_1/train/ckpt-130
# Epoch 150 Loss 0.1053 Accuracy 0.9667
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 155 at ./icub_testing/checkpoints_fold_1/train/ckpt-131
# Epoch 155 Loss 0.0728 Accuracy 0.9767
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 160 at ./icub_testing/checkpoints_fold_1/train/ckpt-132
# Epoch 160 Loss 0.1011 Accuracy 0.9700
# Time taken for 1 epoch: 0.17 secs
# Saving checkpoint for epoch 165 at ./icub_testing/checkpoints_fold_1/train/ckpt-133
# Epoch 165 Loss 0.1981 Accuracy 0.9617
# Time taken for 1 epoch: 0.18 secs
#
# Saving checkpoint for epoch 170 at ./icub_testing/checkpoints_fold_1/train/ckpt-134
# Epoch 170 Loss 0.0798 Accuracy 0.9733
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 175 at ./icub_testing/checkpoints_fold_1/train/ckpt-135
# Epoch 175 Loss 0.1787 Accuracy 0.9550
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 180 at ./icub_testing/checkpoints_fold_1/train/ckpt-136
# Epoch 180 Loss 0.0855 Accuracy 0.9717
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 185 at ./icub_testing/checkpoints_fold_1/train/ckpt-137
# Epoch 185 Loss 0.0732 Accuracy 0.9750
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 190 at ./icub_testing/checkpoints_fold_1/train/ckpt-138
# Epoch 190 Loss 0.0754 Accuracy 0.9683
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 195 at ./icub_testing/checkpoints_fold_1/train/ckpt-139
# Epoch 195 Loss 0.1186 Accuracy 0.9667
# Time taken for 1 epoch: 0.18 secs
#
# Saving checkpoint for epoch 200 at ./icub_testing/checkpoints_fold_1/train/ckpt-140
# Epoch 200 Loss 0.0789 Accuracy 0.9667
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 205 at ./icub_testing/checkpoints_fold_1/train/ckpt-141
# Epoch 205 Loss 0.0695 Accuracy 0.9767
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 210 at ./icub_testing/checkpoints_fold_1/train/ckpt-142
# Epoch 210 Loss 0.1178 Accuracy 0.9617
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 215 at ./icub_testing/checkpoints_fold_1/train/ckpt-143
# Epoch 215 Loss 0.2372 Accuracy 0.9333
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 220 at ./icub_testing/checkpoints_fold_1/train/ckpt-144
# Epoch 220 Loss 0.1008 Accuracy 0.9667
# Time taken for 1 epoch: 0.18 secs
#
# Saving checkpoint for epoch 225 at ./icub_testing/checkpoints_fold_1/train/ckpt-145
# Epoch 225 Loss 0.0840 Accuracy 0.9733
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 230 at ./icub_testing/checkpoints_fold_1/train/ckpt-146
# Epoch 230 Loss 0.0748 Accuracy 0.9733
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 235 at ./icub_testing/checkpoints_fold_1/train/ckpt-147
# Epoch 235 Loss 0.1492 Accuracy 0.9567
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 240 at ./icub_testing/checkpoints_fold_1/train/ckpt-148
# Epoch 240 Loss 0.0590 Accuracy 0.9733
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 245 at ./icub_testing/checkpoints_fold_1/train/ckpt-149
# Epoch 245 Loss 0.1867 Accuracy 0.9400
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 250 at ./icub_testing/checkpoints_fold_1/train/ckpt-150
# Epoch 250 Loss 0.0600 Accuracy 0.9783
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 255 at ./icub_testing/checkpoints_fold_1/train/ckpt-151
# Epoch 255 Loss 0.0771 Accuracy 0.9733
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 260 at ./icub_testing/checkpoints_fold_1/train/ckpt-152
# Epoch 260 Loss 0.0492 Accuracy 0.9817
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 265 at ./icub_testing/checkpoints_fold_1/train/ckpt-153
# Epoch 265 Loss 0.3376 Accuracy 0.9317
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 270 at ./icub_testing/checkpoints_fold_1/train/ckpt-154
# Epoch 270 Loss 0.1101 Accuracy 0.9667
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 275 at ./icub_testing/checkpoints_fold_1/train/ckpt-155
# Epoch 275 Loss 0.0718 Accuracy 0.9733
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 280 at ./icub_testing/checkpoints_fold_1/train/ckpt-156
# Epoch 280 Loss 0.1898 Accuracy 0.9467
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 285 at ./icub_testing/checkpoints_fold_1/train/ckpt-157
# Epoch 285 Loss 0.0438 Accuracy 0.9867
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 290 at ./icub_testing/checkpoints_fold_1/train/ckpt-158
# Epoch 290 Loss 0.0476 Accuracy 0.9800
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 295 at ./icub_testing/checkpoints_fold_1/train/ckpt-159
# Epoch 295 Loss 0.0594 Accuracy 0.9817
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 300 at ./icub_testing/checkpoints_fold_1/train/ckpt-160
# Epoch 300 Loss 0.2704 Accuracy 0.9367
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 305 at ./icub_testing/checkpoints_fold_1/train/ckpt-161
# Epoch 305 Loss 0.1617 Accuracy 0.9650
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 310 at ./icub_testing/checkpoints_fold_1/train/ckpt-162
# Epoch 310 Loss 0.1134 Accuracy 0.9583
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 315 at ./icub_testing/checkpoints_fold_1/train/ckpt-163
# Epoch 315 Loss 0.0967 Accuracy 0.9667
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 320 at ./icub_testing/checkpoints_fold_1/train/ckpt-164
# Epoch 320 Loss 0.0523 Accuracy 0.9800
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 325 at ./icub_testing/checkpoints_fold_1/train/ckpt-165
# Epoch 325 Loss 0.0727 Accuracy 0.9700
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 330 at ./icub_testing/checkpoints_fold_1/train/ckpt-166
# Epoch 330 Loss 0.2133 Accuracy 0.9450
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 335 at ./icub_testing/checkpoints_fold_1/train/ckpt-167
# Epoch 335 Loss 0.1033 Accuracy 0.9617
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 340 at ./icub_testing/checkpoints_fold_1/train/ckpt-168
# Epoch 340 Loss 0.0533 Accuracy 0.9833
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 345 at ./icub_testing/checkpoints_fold_1/train/ckpt-169
# Epoch 345 Loss 0.0948 Accuracy 0.9667
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 350 at ./icub_testing/checkpoints_fold_1/train/ckpt-170
# Epoch 350 Loss 0.0944 Accuracy 0.9633
# Time taken for 1 epoch: 0.14 secs
#
# Saving checkpoint for epoch 355 at ./icub_testing/checkpoints_fold_1/train/ckpt-171
# Epoch 355 Loss 0.2091 Accuracy 0.9483
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 360 at ./icub_testing/checkpoints_fold_1/train/ckpt-172
# Epoch 360 Loss 0.1498 Accuracy 0.9567
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 365 at ./icub_testing/checkpoints_fold_1/train/ckpt-173
# Epoch 365 Loss 0.0914 Accuracy 0.9783
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 370 at ./icub_testing/checkpoints_fold_1/train/ckpt-174
# Epoch 370 Loss 0.0544 Accuracy 0.9800
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 375 at ./icub_testing/checkpoints_fold_1/train/ckpt-175
# Epoch 375 Loss 0.0434 Accuracy 0.9883
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 380 at ./icub_testing/checkpoints_fold_1/train/ckpt-176
# Epoch 380 Loss 0.1234 Accuracy 0.9633
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 385 at ./icub_testing/checkpoints_fold_1/train/ckpt-177
# Epoch 385 Loss 0.0678 Accuracy 0.9733
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 390 at ./icub_testing/checkpoints_fold_1/train/ckpt-178
# Epoch 390 Loss 0.0875 Accuracy 0.9750
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 395 at ./icub_testing/checkpoints_fold_1/train/ckpt-179
# Epoch 395 Loss 0.0934 Accuracy 0.9650
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 400 at ./icub_testing/checkpoints_fold_1/train/ckpt-180
# Epoch 400 Loss 0.0592 Accuracy 0.9783
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 405 at ./icub_testing/checkpoints_fold_1/train/ckpt-181
# Epoch 405 Loss 0.0491 Accuracy 0.9850
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 410 at ./icub_testing/checkpoints_fold_1/train/ckpt-182
# Epoch 410 Loss 0.1115 Accuracy 0.9617
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 415 at ./icub_testing/checkpoints_fold_1/train/ckpt-183
# Epoch 415 Loss 0.3282 Accuracy 0.9117
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 420 at ./icub_testing/checkpoints_fold_1/train/ckpt-184
# Epoch 420 Loss 0.1656 Accuracy 0.9617
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 425 at ./icub_testing/checkpoints_fold_1/train/ckpt-185
# Epoch 425 Loss 0.0648 Accuracy 0.9800
# Time taken for 1 epoch: 0.16 secs
# Saving checkpoint for epoch 430 at ./icub_testing/checkpoints_fold_1/train/ckpt-186
# Epoch 430 Loss 0.0799 Accuracy 0.9683
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 435 at ./icub_testing/checkpoints_fold_1/train/ckpt-187
# Epoch 435 Loss 0.0392 Accuracy 0.9867
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 440 at ./icub_testing/checkpoints_fold_1/train/ckpt-188
# Epoch 440 Loss 0.0580 Accuracy 0.9800
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 445 at ./icub_testing/checkpoints_fold_1/train/ckpt-189
# Epoch 445 Loss 0.1155 Accuracy 0.9633
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 450 at ./icub_testing/checkpoints_fold_1/train/ckpt-190
# Epoch 450 Loss 0.1491 Accuracy 0.9650
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 455 at ./icub_testing/checkpoints_fold_1/train/ckpt-191
# Epoch 455 Loss 0.0349 Accuracy 0.9867
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 460 at ./icub_testing/checkpoints_fold_1/train/ckpt-192
# Epoch 460 Loss 0.0598 Accuracy 0.9767
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 465 at ./icub_testing/checkpoints_fold_1/train/ckpt-193
# Epoch 465 Loss 0.0712 Accuracy 0.9767
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 470 at ./icub_testing/checkpoints_fold_1/train/ckpt-194
# Epoch 470 Loss 0.0423 Accuracy 0.9850
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 475 at ./icub_testing/checkpoints_fold_1/train/ckpt-195
# Epoch 475 Loss 0.1143 Accuracy 0.9650
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 480 at ./icub_testing/checkpoints_fold_1/train/ckpt-196
# Epoch 480 Loss 0.0538 Accuracy 0.9783
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 485 at ./icub_testing/checkpoints_fold_1/train/ckpt-197
# Epoch 485 Loss 0.0334 Accuracy 0.9917
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 490 at ./icub_testing/checkpoints_fold_1/train/ckpt-198
# Epoch 490 Loss 0.0376 Accuracy 0.9867
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 495 at ./icub_testing/checkpoints_fold_1/train/ckpt-199
# Epoch 495 Loss 0.0603 Accuracy 0.9800
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 500 at ./icub_testing/checkpoints_fold_1/train/ckpt-200
# Epoch 500 Loss 0.1518 Accuracy 0.9617
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 505 at ./icub_testing/checkpoints_fold_1/train/ckpt-201
# Epoch 505 Loss 0.0286 Accuracy 0.9917
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 510 at ./icub_testing/checkpoints_fold_1/train/ckpt-202
# Epoch 510 Loss 0.1187 Accuracy 0.9683
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 515 at ./icub_testing/checkpoints_fold_1/train/ckpt-203
# Epoch 515 Loss 0.1517 Accuracy 0.9583
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 520 at ./icub_testing/checkpoints_fold_1/train/ckpt-204
# Epoch 520 Loss 0.1177 Accuracy 0.9650
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 525 at ./icub_testing/checkpoints_fold_1/train/ckpt-205
# Epoch 525 Loss 0.0994 Accuracy 0.9750
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 530 at ./icub_testing/checkpoints_fold_1/train/ckpt-206
# Epoch 530 Loss 0.0508 Accuracy 0.9783
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 535 at ./icub_testing/checkpoints_fold_1/train/ckpt-207
# Epoch 535 Loss 0.0335 Accuracy 0.9900
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 540 at ./icub_testing/checkpoints_fold_1/train/ckpt-208
# Epoch 540 Loss 0.0804 Accuracy 0.9767
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 545 at ./icub_testing/checkpoints_fold_1/train/ckpt-209
# Epoch 545 Loss 0.1712 Accuracy 0.9550
# Time taken for 1 epoch: 0.14 secs
#
# Saving checkpoint for epoch 550 at ./icub_testing/checkpoints_fold_1/train/ckpt-210
# Epoch 550 Loss 0.0564 Accuracy 0.9850
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 555 at ./icub_testing/checkpoints_fold_1/train/ckpt-211
# Epoch 555 Loss 0.0469 Accuracy 0.9817
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 560 at ./icub_testing/checkpoints_fold_1/train/ckpt-212
# Epoch 560 Loss 0.0547 Accuracy 0.9800
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 565 at ./icub_testing/checkpoints_fold_1/train/ckpt-213
# Epoch 565 Loss 0.0735 Accuracy 0.9733
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 570 at ./icub_testing/checkpoints_fold_1/train/ckpt-214
# Epoch 570 Loss 0.1166 Accuracy 0.9650
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 575 at ./icub_testing/checkpoints_fold_1/train/ckpt-215
# Epoch 575 Loss 0.0707 Accuracy 0.9700
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 580 at ./icub_testing/checkpoints_fold_1/train/ckpt-216
# Epoch 580 Loss 0.0794 Accuracy 0.9767
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 585 at ./icub_testing/checkpoints_fold_1/train/ckpt-217
# Epoch 585 Loss 0.0426 Accuracy 0.9833
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 590 at ./icub_testing/checkpoints_fold_1/train/ckpt-218
# Epoch 590 Loss 0.1561 Accuracy 0.9500
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 595 at ./icub_testing/checkpoints_fold_1/train/ckpt-219
# Epoch 595 Loss 0.0493 Accuracy 0.9850
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 600 at ./icub_testing/checkpoints_fold_1/train/ckpt-220
# Epoch 600 Loss 0.0381 Accuracy 0.9833
# Time taken for 1 epoch: 0.17 secs
#
# ................................................................................
# Starting eval on fold 1 ...
# Test dataset accuracy: 0.9750
# Starting sequence eval on fold 1 ...
# ................................................................................
# Loading Datasets - k-fold =  2
# ................................................................................
# BioTac training dataset shape:  (600, 400, 19)
# Icub training dataset shape:  (600, 75, 6, 10, 1)
# BioTac validation dataset shape:  (200, 400, 19)
# Icub validation dataset shape:  (200, 75, 6, 10, 1)
# ................................................................................
# Latest checkpoint restored!!
# Saving checkpoint for epoch 5 at ./icub_testing/checkpoints_fold_2/train/ckpt-101
# Epoch 5 Loss 0.1833 Accuracy 0.9367
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 10 at ./icub_testing/checkpoints_fold_2/train/ckpt-102
# Epoch 10 Loss 0.1639 Accuracy 0.9533
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 15 at ./icub_testing/checkpoints_fold_2/train/ckpt-103
# Epoch 15 Loss 0.2339 Accuracy 0.9200
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 20 at ./icub_testing/checkpoints_fold_2/train/ckpt-104
# Epoch 20 Loss 0.1832 Accuracy 0.9300
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 25 at ./icub_testing/checkpoints_fold_2/train/ckpt-105
# Epoch 25 Loss 0.2629 Accuracy 0.9133
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 30 at ./icub_testing/checkpoints_fold_2/train/ckpt-106
# Epoch 30 Loss 0.0817 Accuracy 0.9650
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 35 at ./icub_testing/checkpoints_fold_2/train/ckpt-107
# Epoch 35 Loss 0.2994 Accuracy 0.9217
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 40 at ./icub_testing/checkpoints_fold_2/train/ckpt-108
# Epoch 40 Loss 0.0889 Accuracy 0.9700
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 45 at ./icub_testing/checkpoints_fold_2/train/ckpt-109
# Epoch 45 Loss 0.1610 Accuracy 0.9550
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 50 at ./icub_testing/checkpoints_fold_2/train/ckpt-110
# Epoch 50 Loss 0.2529 Accuracy 0.9200
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 55 at ./icub_testing/checkpoints_fold_2/train/ckpt-111
# Epoch 55 Loss 0.1648 Accuracy 0.9500
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 60 at ./icub_testing/checkpoints_fold_2/train/ckpt-112
# Epoch 60 Loss 0.1435 Accuracy 0.9433
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 65 at ./icub_testing/checkpoints_fold_2/train/ckpt-113
# Epoch 65 Loss 0.1431 Accuracy 0.9433
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 70 at ./icub_testing/checkpoints_fold_2/train/ckpt-114
# Epoch 70 Loss 0.1989 Accuracy 0.9417
# Time taken for 1 epoch: 0.16 secs
# Saving checkpoint for epoch 75 at ./icub_testing/checkpoints_fold_2/train/ckpt-115
# Epoch 75 Loss 0.1565 Accuracy 0.9500
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 80 at ./icub_testing/checkpoints_fold_2/train/ckpt-116
# Epoch 80 Loss 0.0721 Accuracy 0.9700
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 85 at ./icub_testing/checkpoints_fold_2/train/ckpt-117
# Epoch 85 Loss 0.1479 Accuracy 0.9517
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 90 at ./icub_testing/checkpoints_fold_2/train/ckpt-118
# Epoch 90 Loss 0.0770 Accuracy 0.9733
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 95 at ./icub_testing/checkpoints_fold_2/train/ckpt-119
# Epoch 95 Loss 0.0971 Accuracy 0.9550
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 100 at ./icub_testing/checkpoints_fold_2/train/ckpt-120
# Epoch 100 Loss 0.2954 Accuracy 0.9200
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 105 at ./icub_testing/checkpoints_fold_2/train/ckpt-121
# Epoch 105 Loss 0.0908 Accuracy 0.9733
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 110 at ./icub_testing/checkpoints_fold_2/train/ckpt-122
# Epoch 110 Loss 0.1119 Accuracy 0.9583
# Time taken for 1 epoch: 0.18 secs
#
# Saving checkpoint for epoch 115 at ./icub_testing/checkpoints_fold_2/train/ckpt-123
# Epoch 115 Loss 0.1408 Accuracy 0.9400
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 120 at ./icub_testing/checkpoints_fold_2/train/ckpt-124
# Epoch 120 Loss 0.1214 Accuracy 0.9650
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 125 at ./icub_testing/checkpoints_fold_2/train/ckpt-125
# Epoch 125 Loss 0.1650 Accuracy 0.9333
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 130 at ./icub_testing/checkpoints_fold_2/train/ckpt-126
# Epoch 130 Loss 0.1558 Accuracy 0.9533
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 135 at ./icub_testing/checkpoints_fold_2/train/ckpt-127
# Epoch 135 Loss 0.1386 Accuracy 0.9567
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 140 at ./icub_testing/checkpoints_fold_2/train/ckpt-128
# Epoch 140 Loss 0.1595 Accuracy 0.9483
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 145 at ./icub_testing/checkpoints_fold_2/train/ckpt-129
# Epoch 145 Loss 0.1853 Accuracy 0.9550
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 150 at ./icub_testing/checkpoints_fold_2/train/ckpt-130
# Epoch 150 Loss 0.0996 Accuracy 0.9533
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 155 at ./icub_testing/checkpoints_fold_2/train/ckpt-131
# Epoch 155 Loss 0.1192 Accuracy 0.9550
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 160 at ./icub_testing/checkpoints_fold_2/train/ckpt-132
# Epoch 160 Loss 0.1315 Accuracy 0.9517
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 165 at ./icub_testing/checkpoints_fold_2/train/ckpt-133
# Epoch 165 Loss 0.0881 Accuracy 0.9700
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 170 at ./icub_testing/checkpoints_fold_2/train/ckpt-134
# Epoch 170 Loss 0.0615 Accuracy 0.9800
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 175 at ./icub_testing/checkpoints_fold_2/train/ckpt-135
# Epoch 175 Loss 0.2800 Accuracy 0.9167
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 180 at ./icub_testing/checkpoints_fold_2/train/ckpt-136
# Epoch 180 Loss 0.1845 Accuracy 0.9500
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 185 at ./icub_testing/checkpoints_fold_2/train/ckpt-137
# Epoch 185 Loss 0.1058 Accuracy 0.9617
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 190 at ./icub_testing/checkpoints_fold_2/train/ckpt-138
# Epoch 190 Loss 0.1737 Accuracy 0.9500
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 195 at ./icub_testing/checkpoints_fold_2/train/ckpt-139
# Epoch 195 Loss 0.0714 Accuracy 0.9683
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 200 at ./icub_testing/checkpoints_fold_2/train/ckpt-140
# Epoch 200 Loss 0.1091 Accuracy 0.9650
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 205 at ./icub_testing/checkpoints_fold_2/train/ckpt-141
# Epoch 205 Loss 0.0802 Accuracy 0.9683
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 210 at ./icub_testing/checkpoints_fold_2/train/ckpt-142
# Epoch 210 Loss 0.0706 Accuracy 0.9717
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 215 at ./icub_testing/checkpoints_fold_2/train/ckpt-143
# Epoch 215 Loss 0.0998 Accuracy 0.9650
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 220 at ./icub_testing/checkpoints_fold_2/train/ckpt-144
# Epoch 220 Loss 0.0854 Accuracy 0.9700
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 225 at ./icub_testing/checkpoints_fold_2/train/ckpt-145
# Epoch 225 Loss 0.1211 Accuracy 0.9583
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 230 at ./icub_testing/checkpoints_fold_2/train/ckpt-146
# Epoch 230 Loss 0.1029 Accuracy 0.9533
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 235 at ./icub_testing/checkpoints_fold_2/train/ckpt-147
# Epoch 235 Loss 0.1335 Accuracy 0.9633
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 240 at ./icub_testing/checkpoints_fold_2/train/ckpt-148
# Epoch 240 Loss 0.2385 Accuracy 0.9200
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 245 at ./icub_testing/checkpoints_fold_2/train/ckpt-149
# Epoch 245 Loss 0.2465 Accuracy 0.9233
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 250 at ./icub_testing/checkpoints_fold_2/train/ckpt-150
# Epoch 250 Loss 0.1303 Accuracy 0.9617
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 255 at ./icub_testing/checkpoints_fold_2/train/ckpt-151
# Epoch 255 Loss 0.0736 Accuracy 0.9700
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 260 at ./icub_testing/checkpoints_fold_2/train/ckpt-152
# Epoch 260 Loss 0.0571 Accuracy 0.9800
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 265 at ./icub_testing/checkpoints_fold_2/train/ckpt-153
# Epoch 265 Loss 0.1040 Accuracy 0.9600
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 270 at ./icub_testing/checkpoints_fold_2/train/ckpt-154
# Epoch 270 Loss 0.0761 Accuracy 0.9650
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 275 at ./icub_testing/checkpoints_fold_2/train/ckpt-155
# Epoch 275 Loss 0.1665 Accuracy 0.9350
# Time taken for 1 epoch: 0.16 secs
#
# ...
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 105 at ./icub_testing/checkpoints_fold_3/train/ckpt-121
# Epoch 105 Loss 0.1703 Accuracy 0.9433
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 110 at ./icub_testing/checkpoints_fold_3/train/ckpt-122
# Epoch 110 Loss 0.0617 Accuracy 0.9833
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 115 at ./icub_testing/checkpoints_fold_3/train/ckpt-123
# Epoch 115 Loss 0.1169 Accuracy 0.9533
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 120 at ./icub_testing/checkpoints_fold_3/train/ckpt-124
# Epoch 120 Loss 0.0672 Accuracy 0.9800
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 125 at ./icub_testing/checkpoints_fold_3/train/ckpt-125
# Epoch 125 Loss 0.2260 Accuracy 0.9300
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 130 at ./icub_testing/checkpoints_fold_3/train/ckpt-126
# Epoch 130 Loss 0.2913 Accuracy 0.9283
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 135 at ./icub_testing/checkpoints_fold_3/train/ckpt-127
# Epoch 135 Loss 0.0615 Accuracy 0.9733
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 140 at ./icub_testing/checkpoints_fold_3/train/ckpt-128
# Epoch 140 Loss 0.2137 Accuracy 0.9400
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 145 at ./icub_testing/checkpoints_fold_3/train/ckpt-129
# Epoch 145 Loss 0.2674 Accuracy 0.9200
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 150 at ./icub_testing/checkpoints_fold_3/train/ckpt-130
# Epoch 150 Loss 0.0866 Accuracy 0.9683
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 155 at ./icub_testing/checkpoints_fold_3/train/ckpt-131
# Epoch 155 Loss 0.1620 Accuracy 0.9483
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 160 at ./icub_testing/checkpoints_fold_3/train/ckpt-132
# Epoch 160 Loss 0.0541 Accuracy 0.9800
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 165 at ./icub_testing/checkpoints_fold_3/train/ckpt-133
# Epoch 165 Loss 0.0939 Accuracy 0.9717
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 170 at ./icub_testing/checkpoints_fold_3/train/ckpt-134
# Epoch 170 Loss 0.0999 Accuracy 0.9700
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 175 at ./icub_testing/checkpoints_fold_3/train/ckpt-135
# Epoch 175 Loss 0.1182 Accuracy 0.9567
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 180 at ./icub_testing/checkpoints_fold_3/train/ckpt-136
# Epoch 180 Loss 0.0696 Accuracy 0.9767
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 185 at ./icub_testing/checkpoints_fold_3/train/ckpt-137
# Epoch 185 Loss 0.1981 Accuracy 0.9400
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 190 at ./icub_testing/checkpoints_fold_3/train/ckpt-138
# Epoch 190 Loss 0.2027 Accuracy 0.9467
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 195 at ./icub_testing/checkpoints_fold_3/train/ckpt-139
# Epoch 195 Loss 0.0551 Accuracy 0.9783
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 200 at ./icub_testing/checkpoints_fold_3/train/ckpt-140
# Epoch 200 Loss 0.0627 Accuracy 0.9717
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 205 at ./icub_testing/checkpoints_fold_3/train/ckpt-141
# Epoch 205 Loss 0.2550 Accuracy 0.9333
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 210 at ./icub_testing/checkpoints_fold_3/train/ckpt-142
# Epoch 210 Loss 0.0862 Accuracy 0.9683
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 215 at ./icub_testing/checkpoints_fold_3/train/ckpt-143
# Epoch 215 Loss 0.0436 Accuracy 0.9817
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 220 at ./icub_testing/checkpoints_fold_3/train/ckpt-144
# Epoch 220 Loss 0.0870 Accuracy 0.9683
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 225 at ./icub_testing/checkpoints_fold_3/train/ckpt-145
# Epoch 225 Loss 0.0777 Accuracy 0.9767
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 230 at ./icub_testing/checkpoints_fold_3/train/ckpt-146
# Epoch 230 Loss 0.0651 Accuracy 0.9800
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 235 at ./icub_testing/checkpoints_fold_3/train/ckpt-147
# Epoch 235 Loss 0.1525 Accuracy 0.9567
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 240 at ./icub_testing/checkpoints_fold_3/train/ckpt-148
# Epoch 240 Loss 0.0504 Accuracy 0.9817
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 245 at ./icub_testing/checkpoints_fold_3/train/ckpt-149
# Epoch 245 Loss 0.2268 Accuracy 0.9417
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 250 at ./icub_testing/checkpoints_fold_3/train/ckpt-150
# Epoch 250 Loss 0.1573 Accuracy 0.9550
# Time taken for 1 epoch: 0.17 secs
# Saving checkpoint for epoch 255 at ./icub_testing/checkpoints_fold_3/train/ckpt-151
# Epoch 255 Loss 0.0529 Accuracy 0.9800
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 260 at ./icub_testing/checkpoints_fold_3/train/ckpt-152
# Epoch 260 Loss 0.0479 Accuracy 0.9817
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 265 at ./icub_testing/checkpoints_fold_3/train/ckpt-153
# Epoch 265 Loss 0.0687 Accuracy 0.9717
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 270 at ./icub_testing/checkpoints_fold_3/train/ckpt-154
# Epoch 270 Loss 0.1866 Accuracy 0.9533
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 275 at ./icub_testing/checkpoints_fold_3/train/ckpt-155
# Epoch 275 Loss 0.1545 Accuracy 0.9617
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 280 at ./icub_testing/checkpoints_fold_3/train/ckpt-156
# Epoch 280 Loss 0.0550 Accuracy 0.9767
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 285 at ./icub_testing/checkpoints_fold_3/train/ckpt-157
# Epoch 285 Loss 0.0766 Accuracy 0.9733
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 290 at ./icub_testing/checkpoints_fold_3/train/ckpt-158
# Epoch 290 Loss 0.0663 Accuracy 0.9700
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 295 at ./icub_testing/checkpoints_fold_3/train/ckpt-159
# Epoch 295 Loss 0.2068 Accuracy 0.9383
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 300 at ./icub_testing/checkpoints_fold_3/train/ckpt-160
# Epoch 300 Loss 0.0816 Accuracy 0.9650
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 305 at ./icub_testing/checkpoints_fold_3/train/ckpt-161
# Epoch 305 Loss 0.0798 Accuracy 0.9717
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 310 at ./icub_testing/checkpoints_fold_3/train/ckpt-162
# Epoch 310 Loss 0.1255 Accuracy 0.9583
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 315 at ./icub_testing/checkpoints_fold_3/train/ckpt-163
# Epoch 315 Loss 0.3367 Accuracy 0.9300
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 320 at ./icub_testing/checkpoints_fold_3/train/ckpt-164
# Epoch 320 Loss 0.2131 Accuracy 0.9617
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 325 at ./icub_testing/checkpoints_fold_3/train/ckpt-165
# Epoch 325 Loss 0.1117 Accuracy 0.9700
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 330 at ./icub_testing/checkpoints_fold_3/train/ckpt-166
# Epoch 330 Loss 0.1767 Accuracy 0.9533
# Time taken for 1 epoch: 0.25 secs
#
# Saving checkpoint for epoch 335 at ./icub_testing/checkpoints_fold_3/train/ckpt-167
# Epoch 335 Loss 0.1721 Accuracy 0.9383
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 340 at ./icub_testing/checkpoints_fold_3/train/ckpt-168
# Epoch 340 Loss 0.0635 Accuracy 0.9800
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 345 at ./icub_testing/checkpoints_fold_3/train/ckpt-169
# Epoch 345 Loss 0.0479 Accuracy 0.9850
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 350 at ./icub_testing/checkpoints_fold_3/train/ckpt-170
# Epoch 350 Loss 0.2205 Accuracy 0.9367
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 355 at ./icub_testing/checkpoints_fold_3/train/ckpt-171
# Epoch 355 Loss 0.1810 Accuracy 0.9483
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 360 at ./icub_testing/checkpoints_fold_3/train/ckpt-172
# Epoch 360 Loss 0.0504 Accuracy 0.9817
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 365 at ./icub_testing/checkpoints_fold_3/train/ckpt-173
# Epoch 365 Loss 0.2154 Accuracy 0.9417
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 370 at ./icub_testing/checkpoints_fold_3/train/ckpt-174
# Epoch 370 Loss 0.1432 Accuracy 0.9583
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 375 at ./icub_testing/checkpoints_fold_3/train/ckpt-175
# Epoch 375 Loss 0.0810 Accuracy 0.9733
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 380 at ./icub_testing/checkpoints_fold_3/train/ckpt-176
# Epoch 380 Loss 0.0902 Accuracy 0.9733
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 385 at ./icub_testing/checkpoints_fold_3/train/ckpt-177
# Epoch 385 Loss 0.1681 Accuracy 0.9533
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 390 at ./icub_testing/checkpoints_fold_3/train/ckpt-178
# Epoch 390 Loss 0.0380 Accuracy 0.9833
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 395 at ./icub_testing/checkpoints_fold_3/train/ckpt-179
# Epoch 395 Loss 0.2732 Accuracy 0.9367
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 400 at ./icub_testing/checkpoints_fold_3/train/ckpt-180
# Epoch 400 Loss 0.0687 Accuracy 0.9683
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 405 at ./icub_testing/checkpoints_fold_3/train/ckpt-181
# Epoch 405 Loss 0.0739 Accuracy 0.9750
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 410 at ./icub_testing/checkpoints_fold_3/train/ckpt-182
# Epoch 410 Loss 0.1867 Accuracy 0.9500
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 415 at ./icub_testing/checkpoints_fold_3/train/ckpt-183
# Epoch 415 Loss 0.2352 Accuracy 0.9317
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 420 at ./icub_testing/checkpoints_fold_3/train/ckpt-184
# Epoch 420 Loss 0.1228 Accuracy 0.9667
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 425 at ./icub_testing/checkpoints_fold_3/train/ckpt-185
# Epoch 425 Loss 0.1644 Accuracy 0.9500
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 430 at ./icub_testing/checkpoints_fold_3/train/ckpt-186
# Epoch 430 Loss 0.0488 Accuracy 0.9833
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 435 at ./icub_testing/checkpoints_fold_3/train/ckpt-187
# Epoch 435 Loss 0.0471 Accuracy 0.9883
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 440 at ./icub_testing/checkpoints_fold_3/train/ckpt-188
# Epoch 440 Loss 0.0549 Accuracy 0.9800
# Time taken for 1 epoch: 0.18 secs
#
# Saving checkpoint for epoch 445 at ./icub_testing/checkpoints_fold_3/train/ckpt-189
# Epoch 445 Loss 0.0451 Accuracy 0.9800
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 450 at ./icub_testing/checkpoints_fold_3/train/ckpt-190
# Epoch 450 Loss 0.0590 Accuracy 0.9783
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 455 at ./icub_testing/checkpoints_fold_3/train/ckpt-191
# Epoch 455 Loss 0.1485 Accuracy 0.9583
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 460 at ./icub_testing/checkpoints_fold_3/train/ckpt-192
# Epoch 460 Loss 0.0385 Accuracy 0.9900
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 465 at ./icub_testing/checkpoints_fold_3/train/ckpt-193
# Epoch 465 Loss 0.0692 Accuracy 0.9767
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 470 at ./icub_testing/checkpoints_fold_3/train/ckpt-194
# Epoch 470 Loss 0.0681 Accuracy 0.9767
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 475 at ./icub_testing/checkpoints_fold_3/train/ckpt-195
# Epoch 475 Loss 0.0672 Accuracy 0.9750
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 480 at ./icub_testing/checkpoints_fold_3/train/ckpt-196
# Epoch 480 Loss 0.0563 Accuracy 0.9800
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 485 at ./icub_testing/checkpoints_fold_3/train/ckpt-197
# Epoch 485 Loss 0.0506 Accuracy 0.9783
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 490 at ./icub_testing/checkpoints_fold_3/train/ckpt-198
# Epoch 490 Loss 0.0530 Accuracy 0.9783
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 495 at ./icub_testing/checkpoints_fold_3/train/ckpt-199
# Epoch 495 Loss 0.1528 Accuracy 0.9650
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 500 at ./icub_testing/checkpoints_fold_3/train/ckpt-200
# Epoch 500 Loss 0.0980 Accuracy 0.9750
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 505 at ./icub_testing/checkpoints_fold_3/train/ckpt-201
# Epoch 505 Loss 0.0794 Accuracy 0.9767
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 510 at ./icub_testing/checkpoints_fold_3/train/ckpt-202
# Epoch 510 Loss 0.0803 Accuracy 0.9700
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 515 at ./icub_testing/checkpoints_fold_3/train/ckpt-203
# Epoch 515 Loss 0.0903 Accuracy 0.9783
# Time taken for 1 epoch: 0.16 secs
# Saving checkpoint for epoch 520 at ./icub_testing/checkpoints_fold_3/train/ckpt-204
# Epoch 520 Loss 0.1367 Accuracy 0.9550
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 525 at ./icub_testing/checkpoints_fold_3/train/ckpt-205
# Epoch 525 Loss 0.0430 Accuracy 0.9883
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 530 at ./icub_testing/checkpoints_fold_3/train/ckpt-206
# Epoch 530 Loss 0.2065 Accuracy 0.9433
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 535 at ./icub_testing/checkpoints_fold_3/train/ckpt-207
# Epoch 535 Loss 0.0635 Accuracy 0.9733
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 540 at ./icub_testing/checkpoints_fold_3/train/ckpt-208
# Epoch 540 Loss 0.0759 Accuracy 0.9800
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 545 at ./icub_testing/checkpoints_fold_3/train/ckpt-209
# Epoch 545 Loss 0.0679 Accuracy 0.9700
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 550 at ./icub_testing/checkpoints_fold_3/train/ckpt-210
# Epoch 550 Loss 0.1076 Accuracy 0.9683
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 555 at ./icub_testing/checkpoints_fold_3/train/ckpt-211
# Epoch 555 Loss 0.0955 Accuracy 0.9667
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 560 at ./icub_testing/checkpoints_fold_3/train/ckpt-212
# Epoch 560 Loss 0.1548 Accuracy 0.9450
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 565 at ./icub_testing/checkpoints_fold_3/train/ckpt-213
# Epoch 565 Loss 0.0511 Accuracy 0.9850
# Time taken for 1 epoch: 0.15 secs
#
# Saving checkpoint for epoch 570 at ./icub_testing/checkpoints_fold_3/train/ckpt-214
# Epoch 570 Loss 0.0414 Accuracy 0.9883
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 575 at ./icub_testing/checkpoints_fold_3/train/ckpt-215
# Epoch 575 Loss 0.0607 Accuracy 0.9767
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 580 at ./icub_testing/checkpoints_fold_3/train/ckpt-216
# Epoch 580 Loss 0.0749 Accuracy 0.9683
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 585 at ./icub_testing/checkpoints_fold_3/train/ckpt-217
# Epoch 585 Loss 0.0775 Accuracy 0.9800
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 590 at ./icub_testing/checkpoints_fold_3/train/ckpt-218
# Epoch 590 Loss 0.0507 Accuracy 0.9767
# Time taken for 1 epoch: 0.16 secs
#
# Saving checkpoint for epoch 595 at ./icub_testing/checkpoints_fold_3/train/ckpt-219
# Epoch 595 Loss 0.0885 Accuracy 0.9750
# Time taken for 1 epoch: 0.17 secs
#
# Saving checkpoint for epoch 600 at ./icub_testing/checkpoints_fold_3/train/ckpt-220
# Epoch 600 Loss 0.0424 Accuracy 0.9867
# Time taken for 1 epoch: 0.16 secs
#
# ................................................................................
# Starting eval on fold 3 ...
# Test dataset accuracy: 0.9450
# Starting sequence eval on fold 3 ...
# ................................................................................

# %%
overall_accuracy = 0
for i in range(4):
    overall_accuracy += overall_val_accuracy[i].result()
overall_accuracy = overall_accuracy/4
print(f"final accuracy: {overall_accuracy:.4f}")

overall_sequence = tf.reduce_mean(tf.convert_to_tensor(overall_sequential_val_accuracy), axis=-2)
plt.plot(overall_sequence)
plt.ylabel("accuracy")
plt.xlabel("time (s/100)")

plt.show()
# Out:
# final accuracy: 0.9462

# %%
print(f"Peak sequential accuracy: {max(overall_sequence):.4f} at {np.argmax(overall_sequence)/50:.2f}s")
# Out:
# Peak sequential accuracy: 0.9588 at 1.12s
